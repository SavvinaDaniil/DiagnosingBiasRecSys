# %% [markdown]
# # Libraries

# %%
import pickle as pkl
import pandas as pd
import numpy as np
from scipy.stats import mannwhitneyu

# %%
algo_name = "UserKNN"
data_strategies = [
    "uniformly_random",
    "popularity_good",
    "popularity_bad",
    "popularity_good_for_bp_ur",
    "popularity_bad_for_bp_ur",
]

# %% [markdown]
# # Analysis

# %% [markdown]
# ## LKPY

# %%
algo_versions = {
    "UserKNN": [
        {"min_nbrs": 1, "min_sim": 0},
        {"min_nbrs": 2, "min_sim": 0},
        {"min_nbrs": 1, "min_sim": -1},
        {"min_nbrs": 2, "min_sim": -1},
    ],
}

# %%
versions = algo_versions[algo_name]

# %%
file_location = "experimental_results/" + algo_name + "/"

# %%
results = []
for data_strategy in data_strategies:
    for args in versions:
        file = open(file_location + data_strategy + "_" + str(args) + ".pkl", "rb")
        result = pkl.load(file)
        results.append(result)

# %%
stringed_versions = [str(args) for args in versions]

# %%
# Initialize empty lists for the two halves
center = []
min_nbrs = []

# Split the strings and populate the lists
for s in stringed_versions:
    parts = s.split(", ")

    min_nbrs.append(parts[0].split(" ")[-1])
    min_sim.append(parts[1].split(" ")[-1].split("}")[0])

# %%
over_common = ["False"]

# %%
index = pd.MultiIndex.from_product(
    [data_strategies, min_sim, min_nbrs, over_common],
    names=["DataStrategy", "MinimumSimilarity", "MinimumNeighbours", "OverCommon"],
).drop_duplicates()

# %%
results_lkpy = pd.DataFrame(results, index=index)

# %%
results_lkpy
# Out:
#                                                                                                                pop_corr  \
# DataStrategy              MinimumSimilarity MinimumNeighbours OverCommon
# uniformly_random          0                 1                 False        (0.10110466641885223, 3.420017408632659e-17)
#                                             2                 False                           (0.6149052740925817, 0.0)
#                           -1                1                 False         (0.018078800576386483, 0.13261414434946503)
#                                             2                 False       (0.41822601518091973, 3.097865376849624e-291)
# popularity_good           0                 1                 False                           (0.5519601545626697, 0.0)
#                                             2                 False                           (0.5620146001718291, 0.0)
#                           -1                1                 False                           (0.5955040638109448, 0.0)
#                                             2                 False                           (0.6143667114262298, 0.0)
# popularity_bad            0                 1                 False            (0.0247094973664384, 0.0398221911175794)
#                                             2                 False       (0.16076461069841927, 2.7024931290302406e-41)
#                           -1                1                 False                           (0.5591734542833869, 0.0)
#                                             2                 False                           (0.7275483692730526, 0.0)
# popularity_good_for_bp_ur 0                 1                 False                           (0.5878231973071265, 0.0)
#                                             2                 False                            (0.700713136693603, 0.0)
#                           -1                1                 False       (0.25342748511583263, 6.981420795656933e-102)
#                                             2                 False                           (0.7723146452022165, 0.0)
# popularity_bad_for_bp_ur  0                 1                 False        (0.13647389695647674, 3.949716331058841e-30)
#                                             2                 False                           (0.6121275142337781, 0.0)
#                           -1                1                 False        (0.08655989186138914, 5.458030095756707e-13)
#                                             2                 False                           (0.6232556691269233, 0.0)
#
#                                                                            RMSE  \
# DataStrategy              MinimumSimilarity MinimumNeighbours OverCommon
# uniformly_random          0                 1                 False       3.624
#                                             2                 False       3.464
#                           -1                1                 False       3.502
#                                             2                 False       3.352
# popularity_good           0                 1                 False       1.040
#                                             2                 False       1.026
#                           -1                1                 False       1.188
#                                             2                 False       1.190
# popularity_bad            0                 1                 False       1.044
#                                             2                 False       1.034
#                           -1                1                 False       1.182
#                                             2                 False       1.182
#                                             2                 False       1.163025
#                           -1                1                 False       3.545166
#                                             2                 False       1.757001
#
#                                                                             AggDiv
# DataStrategy              MinimumSimilarity MinimumNeighbours OverCommon
# uniformly_random          0                 1                 False       0.340124
#                                             2                 False       0.595145
#                           -1                1                 False       0.400231
#                                             2                 False       0.680826
# popularity_good           0                 1                 False       0.080046
#                                             2                 False       0.172518
#                           -1                1                 False       0.196648
#                                             2                 False       0.339257
# popularity_bad            0                 1                 False       0.511776
#                                             2                 False       0.688195
#                           -1                1                 False       0.262968
#                                             2                 False       0.485190
# popularity_good_for_bp_ur 0                 1                 False       0.349516
#                                             2                 False       0.504551
#                           -1                1                 False       0.487502
#                                             2                 False       0.680971
# popularity_bad_for_bp_ur  0                 1                 False       0.505563
#                                             2                 False       0.674325
#                           -1                1                 False       0.422482
#                                             2                 False       0.679093

# %%
lkpy_dict_detailed = {}
for data_strategy in data_strategies:
    lkpy_detailed_results = []
    for args in versions:
        file = open(file_location + 'correct_detailed_per_item_'+data_strategy + "_" + str(args) + ".pkl", "rb")
        result = pkl.load(file)
        lkpy_detailed_results.append(result)
    lkpy_dict_detailed[data_strategy] = lkpy_detailed_results

# %% [markdown]
# ## Cornac

# %%
algo_versions = {
    "CornacUserKNN": [{"center": True}],
}
algo_name = "CornacUserKNN"

# %%
versions = algo_versions[algo_name]

# %%
file_location = "experimental_results/" + algo_name + "/"

# %%
results = []
for data_strategy in data_strategies:
    for args in versions:
        file = open(file_location + data_strategy + "_" + str(args) + ".pkl", "rb")
        result = pkl.load(file)
        results.append(result)

# %%
stringed_versions = [str(args) for args in versions]

# %%
# Initialize empty lists for the two halves
min_nbrs = []
min_sim = []
# Split the strings and populate the lists
for s in stringed_versions:
    parts = s.split(": ")
    min_nbrs.append(parts[-1].split("}")[0])
    min_sim.append("-1")

# %%
over_common = ["True"]

# %%
index = pd.MultiIndex.from_product(
    [data_strategies, min_sim, min_nbrs, over_common],
    names=["DataStrategy", "MinimumSimilarity", "MinimumNeighbours", "OverCommon"],
).drop_duplicates()

# %%
results_cornac = pd.DataFrame(results, index=index)

# %%
results_cornac.index = results_cornac.index.set_levels(
    results_cornac.index.levels[1].str.replace("-1", "1"), level=2
)

# %%
cornac_dict_detailed = {}
for data_strategy in data_strategies:
    cornac_detailed_results = []
    for args in versions:
        file = open(file_location + 'correct_detailed_per_item_'+data_strategy + "_" + str(args) + ".pkl", "rb")
        result = pkl.load(file)
        cornac_detailed_results.append(result)
    cornac_dict_detailed[data_strategy] = cornac_detailed_results

# %% [markdown]
# # Merge

# %%
user_knn_metrics = (
    pd.concat([results_lkpy, results_cornac])
    .reset_index()
    .sort_values(
        ["DataStrategy", "MinimumSimilarity", "OverCommon", "MinimumNeighbours"]
    )
    .set_index(["DataStrategy", "MinimumSimilarity", "OverCommon", "MinimumNeighbours"])
    .reindex(data_strategies, level=0)
)

# %%
metrics_order = ["pop_corr", "ARP", "ave_PL", "ACLT", "AggDiv", "RMSE", "NDCG"]
user_knn_metrics = user_knn_metrics[metrics_order]

# %%
user_knn_metrics = user_knn_metrics.rename(
    columns={"pop_corr": "PopCorr", "ave_PL": "PL", "ACLT": "APLT", "NDCG": "NDCG@10"}
)

# %%
user_knn_metrics = user_knn_metrics.rename(
    index={
        "uniformly_random": "Scenario 1",
        "popularity_good": "Scenario 2",
        "popularity_bad": "Scenario 3",
        "popularity_good_for_bp_ur": "Scenario 4",
        "popularity_bad_for_bp_ur": "Scenario 5",
    }
)

# %%
user_knn_metrics = user_knn_metrics.reindex(["1", "2", "5", "10"], level=3)

# %%
user_knn_metrics['RealPopCorr'] = user_knn_metrics.PopCorr.apply(lambda x: x[0])
user_knn_metrics['Significance'] = user_knn_metrics.PopCorr.apply(lambda x: True if x[1]<0.005 else False)
user_knn_metrics['PopCorr'] = user_knn_metrics.RealPopCorr 
user_knn_metrics = user_knn_metrics.drop('RealPopCorr', axis=1)

# %%
user_knn_metrics
# Out:
#                                                               PopCorr  \
# DataStrategy MinimumSimilarity OverCommon MinimumNeighbours
# Scenario 1   -1                False      1                  0.018079
#                                           2                  0.418226
#                                True       1                  0.003513
#              0                 False      1                  0.101105
#                                           2                  0.614905
# Scenario 2   -1                False      1                  0.595504
#                                           2                  0.614367
#                                True       1                  0.604307
#              0                 False      1                  0.551960
#                                           2                  0.562015
# Scenario 3   -1                False      1                  0.559173
#                                           2                  0.727548
#                                True       1                  0.521765
#              0                 False      1                  0.024709
#                                           2                  0.160765
# Scenario 4   -1                False      1                  0.253427
#                                           2                  0.772315
#                                True       1                  0.184022
#              0                 False      1                  0.587823
#                                           2                  0.700713
# Scenario 5   -1                False      1                  0.086560
#                                           2                  0.623256
#                                True       1                  0.057401
#              0                 False      1                  0.136474
#                                           2                  0.612128
#
#                                                                   ARP  \
# DataStrategy MinimumSimilarity OverCommon MinimumNeighbours
# Scenario 1   -1                False      1                  0.002059
#                                           2                  0.003528
#                                True       1                  0.001959
#              0                 False      1                  0.002723
#                                           2                  0.005088
# Scenario 2   -1                False      1                  0.020677
#                                           2                  0.022179
#                                True       1                  0.015046
#              0                 False      1                  0.027255
#                                           2                  0.027052
# Scenario 3   -1                False      1                  0.007501
#                                           2                  0.008210
#                                True       1                  0.006448
#              0                 False      1                  0.002130
#                                           2                  0.002811
# Scenario 4   -1                False      1                  0.003283
#                                           2                  0.005797
#                                True       1                  0.002873
#              0                 False      1                  0.007840
#                                           2                  0.013732
# Scenario 5   -1                False      1                  0.002568
#                                           2                  0.004503
#                                True       1                  0.002348
#              0                 False      1                  0.002692
#                                           2                  0.004624
#
#                                                                      PL  \
# DataStrategy MinimumSimilarity OverCommon MinimumNeighbours
# Scenario 1   -1                False      1                  -32.284513
#                                           2                   21.251888
#                                True       1                  -35.745549
#              0                 False      1                  -12.827119
#                                           2                   65.440196
# Scenario 2   -1                False      1                  426.621401
#                                           2                  447.618276
#                                True       1                  305.197289
#              0                 False      1                  632.300469
#                                           2                  591.965761
# Scenario 3   -1                False      1                  187.196940
#                                           2                  192.127212
#                                True       1                  151.685867
#              0                 False      1                  -35.765099
#                                           2                  -13.099813
# Scenario 4   -1                False      1                   23.063081
#                                           2                   97.489880
#                                True       1                    8.669358
#              0                 False      1                  164.548992
#                                           2                  297.046906
# Scenario 5   -1                False      1                   -7.923701
#                                           2                   57.968531
#                                True       1                  -16.243166
#              0                 False      1                  -16.122055
#                                           2                   42.849456
#
#                                                                  APLT  \
# DataStrategy MinimumSimilarity OverCommon MinimumNeighbours
# Scenario 1   -1                False      1                         False
#                                           2                          True
#                                True       1                         False
#              0                 False      1                          True
#                                           2                          True
# Scenario 2   -1                False      1                          True
#                                           2                          True
#                                True       1                          True
#              0                 False      1                          True
#                                           2                          True
# Scenario 3   -1                False      1                          True
#                                           2                          True
#                                True       1                          True
#              0                 False      1                         False
#                                           2                          True
# Scenario 4   -1                False      1                          True
#                                           2                          True
#                                True       1                          True
#              0                 False      1                          True
#                                           2                          True
# Scenario 5   -1                False      1                          True
#                                           2                          True
#                                True       1                          True
#              0                 False      1                          True
#                                           2                          True

# %%
print(user_knn_metrics.drop(['APLT','Significance'], axis=1).round(3).to_latex())
# Out:
# \begin{tabular}{llllrrrrrr}
# \toprule
#            &   &       &   &  PopCorr &    ARP &       PL &  AggDiv &   RMSE &  NDCG@10 \\
# DataStrategy & MinimumSimilarity & OverCommon & MinimumNeighbours &          &        &          &         &        &          \\
# \midrule
# Scenario 1 & -1 & False & 1 &    0.018 &  0.002 &  -32.285 &   0.400 &  3.502 &    0.001 \\
#            &   &       & 2 &    0.418 &  0.004 &   21.252 &   0.681 &  3.352 &    0.003 \\
#            &   & True & 1 &    0.004 &  0.002 &  -35.746 &   0.400 &  3.337 &    0.001 \\
#            & 0 & False & 1 &    0.101 &  0.003 &  -12.827 &   0.340 &  3.624 &    0.002 \\
#            &   &       & 2 &    0.615 &  0.005 &   65.440 &   0.595 &  3.464 &    0.005 \\
# Scenario 2 & -1 & False & 1 &    0.596 &  0.021 &  426.621 &   0.197 &  1.188 &    0.019 \\
#            &   &       & 2 &    0.614 &  0.022 &  447.618 &   0.339 &  1.190 &    0.021 \\
#            &   & True & 1 &    0.604 &  0.015 &  305.197 &   0.238 &  1.150 &    0.013 \\
#            & 0 & False & 1 &    0.552 &  0.027 &  632.300 &   0.080 &  1.040 &    0.023 \\
#            &   &       & 2 &    0.562 &  0.027 &  591.966 &   0.173 &  1.026 &    0.025 \\
# Scenario 3 & -1 & False & 1 &    0.559 &  0.008 &  187.197 &   0.263 &  1.182 &    0.002 \\
#            &   &       & 2 &    0.728 &  0.008 &  192.127 &   0.485 &  1.182 &    0.002 \\
#            &   & True & 1 &    0.522 &  0.006 &  151.686 &   0.290 &  1.151 &    0.001 \\
#            & 0 & False & 1 &    0.025 &  0.002 &  -35.765 &   0.512 &  1.044 &    0.001 \\
#            &   &       & 2 &    0.161 &  0.003 &  -13.100 &   0.688 &  1.034 &    0.004 \\
# Scenario 4 & -1 & False & 1 &    0.253 &  0.003 &   23.063 &   0.488 &  2.502 &    0.001 \\
#            &   &       & 2 &    0.772 &  0.006 &   97.490 &   0.681 &  2.404 &    0.004 \\
#            &   & True & 1 &    0.184 &  0.003 &    8.669 &   0.511 &  2.458 &    0.001 \\
#            & 0 & False & 1 &    0.588 &  0.008 &  164.549 &   0.350 &  2.500 &    0.004 \\
#            &   &       & 2 &    0.701 &  0.014 &  297.047 &   0.505 &  2.386 &    0.010 \\
# Scenario 5 & -1 & False & 1 &    0.087 &  0.003 &   -7.924 &   0.422 &  2.880 &    0.001 \\
#            &   &       & 2 &    0.623 &  0.005 &   57.969 &   0.679 &  2.776 &    0.003 \\
#            &   & True & 1 &    0.057 &  0.002 &  -16.243 &   0.433 &  2.783 &    0.001 \\
#            & 0 & False & 1 &    0.136 &  0.003 &  -16.122 &   0.506 &  2.914 &    0.003 \\
#            &   &       & 2 &    0.612 &  0.005 &   42.849 &   0.674 &  2.794 &    0.006 \\
# \bottomrule
# \end{tabular}

# %%
import pickle

with open("metrics_combined/all_user_knn.pkl", "wb") as f:
    pickle.dump(user_knn_metrics.drop("APLT", axis=1).round(3), f)

# %% [markdown]
# # Significance tests

# %% [markdown]
# ## 1. Average Recommendation Popularity
# recommendation values

# %%
def highest_average(df_list, column_name = 'recommendation'):
    highest_average = -10^6
    highest_i = -1
    for i in range(len(df_list)):
        df = df_list[i]
        mean = np.mean(df[column_name].values)
        #print('mean', mean)
        if mean > highest_average:
            highest_average = mean
            highest_i = i
    print(highest_average, highest_i)
    return highest_average, highest_i

# %%
def mannwhitneyu_test(df_list, alt = 'greater', column_name = 'recommendation'):
    # find the highest average 
    ha, hi = highest_average(df_list, column_name)
    inds_df_list = list(range(len(df_list)))
    to_test_inds = inds_df_list[:hi] + inds_df_list[hi+1:]
    print(to_test_inds)
    df1 = df_list[hi]
    pvalues = []
    for ind in to_test_inds:
        df2 = df_list[ind]
        x = df1[column_name].values
        y = df2[column_name].values
        pvalue = mannwhitneyu(x,y, alternative = alt)[1]
        pvalues.append(pvalue)
    return pvalues # pvalues for all comparisons

# %%
for data_strategy in data_strategies:
    mf_results = cornac_dict_detailed[data_strategy]+lkpy_dict_detailed[data_strategy]
    print(data_strategy)
    print(mannwhitneyu_test(mf_results))
# Out:
# uniformly_random
# 0.005088297816220186 2
# [0, 1, 3, 4]
# [0.0, 0.0, 0.0, 0.0]
# popularity_good
# 0.02725447453965516 1
# [0, 2, 3, 4]
# [0.0, 1.0, 0.0, 0.0]
# popularity_bad
# 0.008210152178837216 4
# [0, 1, 2, 3]
# [1.216560222449918e-85, 0.0, 1.3385517982792135e-307, 4.687712667542103e-27]
# popularity_good_for_bp_ur
# 0.013732259968235063 2
# [0, 1, 3, 4]
# [0.0, 0.0, 0.0, 0.0]
# popularity_bad_for_bp_ur
# 0.0046237003449702396 2
# [0, 1, 3, 4]
# [0.0, 0.0, 0.0, 3.604033785181491e-49]

# %% [markdown]
# ## 2. Popularity Lift

# %%
for data_strategy in data_strategies:
    mf_results = cornac_dict_detailed[data_strategy]+lkpy_dict_detailed[data_strategy]
    for df in mf_results:
        df['popularity_lift'] = (df['recommendation']-df['profile'])/df['profile']*100
    print(mannwhitneyu_test(mf_results, column_name = 'popularity_lift'))
# Out:
# 65.43830590265048 2
# [0, 1, 3, 4]
# [0.0, 2.188941089036555e-258, 0.0, 7.72400099276303e-108]
# 632.2824421667686 1
# [0, 2, 3, 4]
# [0.0, 0.015732623224987266, 2.9669910892081154e-238, 2.7443075046547103e-154]
# 192.12799583548045 4
# [0, 1, 2, 3]
# [1.240145514463707e-36, 0.0, 4.0901184951709577e-150, 2.279407800573683e-12]
# 297.0477047416728 2
# [0, 1, 3, 4]
# [0.0, 8.09724058167196e-264, 0.0, 0.0]
# 57.96919856927836 4
# [0, 1, 2, 3]
# [1.3016235627164633e-199, 8.480723094484795e-77, 1.0, 1.0303011344870575e-153]
